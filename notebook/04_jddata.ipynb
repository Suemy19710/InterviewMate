# %% [markdown]
# # InterviewMate - Resume-JD Matching Analysis with Sentence Transformers
# In this project, I developed and evaluated three different approaches for Resume → Job Description matching:
#
# 1️⃣ Method 1 — Pure Semantic Matching (Sentence-BERT + Cosine Similarity)
#
# 2️⃣ Method 2 — Hybrid Matching (Semantic + Keyword Score)
#
# 3️⃣ Method 3 — Semantic Ranking + Keyword Explanation (Final Chosen Approach)
#
# ### 🔍 Key Findings
#
# 1️⃣ Sentence-BERT consistently delivered the most accurate and meaningful rankings
#
# - It understands context rather than relying on word overlap
#
# - It ranked resumes correctly even when wording differed from the JD
#
# - Scores stabilized around ~0.6 maximum similarity → expected for real-world resume differences
#
# 2️⃣ Hybrid scoring introduced noise
#
# - Generic skills (e.g., SQL, server, testing) appeared across unrelated resumes
#
# - Keyword weighting sometimes pushed incorrect resumes higher
#
# - Although academically interesting, it reduced practical accuracy
#
# 3️⃣ Explanation matters
#
# - Recruiters need to understand why a resume fits
#
# - Adding keyword matching as an explanation layer only provided clarity without hurting performance
#
# - “Why it fits?” + “Missing Skills” transformed the system from purely technical to product-ready

# %%
import pandas as pd
import seaborn as sns
import re
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.metrics.pairwise import cosine_similarity  
from gensim.models import Word2Vec  
from sklearn.model_selection import train_test_split
from sentence_transformers import SentenceTransformer   
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nguye\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('../data/JD/job_dataset.csv')
df.head()
df.shape
# Out:
# (1068, 7)

# %%
df_resume = pd.read_csv('../data/data/processed_data/pdf_data.csv')
df_resume.head()
df_resume.shape
# Out:
# (2484, 7)

# %%
df['Title'].value_counts()
# Out:
# Title
# .NET Developer                  20
# Business Analyst                20
# Copywriter                      20
# Data Engineer                   20
# Digital Marketing Specialist    20
#                                 ..
# Android Architect                1
# iOS Mobile Developer             1
# Junior iOS Developer             1
# iOS App Developer Intern         1
# Graduate iOS Developer           1
# Name: count, Length: 218, dtype: int64

# %%
def build_jd_text(row):
    parts = [
        str(row.get("Title", "")),
        str(row.get("ExperienceLevel", "")),
        str(row.get("YearsOfExperience", "")),
        str(row.get("Skills", "")),
        str(row.get("Responsibilities", "")),
        str(row.get("Keywords", ""))
    ]
    return " ".join(parts)

df["JD_text"] = df.apply(build_jd_text, axis=1)
df.head()
# Out:
#        JobID           Title ExperienceLevel YearsOfExperience  \
# 0  NET-F-001  .NET Developer         Fresher               0-1
# 1  NET-F-002  .NET Developer         Fresher               0-1
# 2  NET-F-003  .NET Developer         Fresher               0-1
# 3  NET-F-004  .NET Developer         Fresher               0-1
# 4  NET-F-005  .NET Developer         Fresher               0-1
#
#                                               Skills  \
# 0  C#; VB.NET basics; .NET Framework; .NET Core f...
# 1  C#; .NET Framework basics; ASP.NET; Razor; HTM...
# 2  C#; VB.NET basics; .NET Core; ASP.NET MVC; HTM...
# 3  C#; .NET Framework; ASP.NET basics; SQL Server...
# 4  C#; ASP.NET; MVC; Entity Framework basics; SQL...
#
#                                     Responsibilities  \
# 0  Assist in coding and debugging applications; L...
# 1  Write simple C# programs under guidance; Suppo...
# 2  Contribute to development of small modules; As...
# 3  Support in software design documentation; Assi...
# 4  Learn to design and build ASP.NET applications...
#
#                                             Keywords  \
# 0  .NET; C#; ASP.NET MVC; Entity Framework; SQL S...
# 1  .NET; C#; ASP.NET MVC; Entity Framework; SQL S...
# 2  .NET; C#; ASP.NET MVC; SQL Server; Entity Fram...
# 3    .NET; C#; SQL Server; Entity Framework; ASP.NET
# 4  .NET; C#; ASP.NET MVC; Entity Framework; SQL S...
#
#                                              JD_text
# 0  .NET Developer Fresher 0-1 C#; VB.NET basics; ...
# 1  .NET Developer Fresher 0-1 C#; .NET Framework ...
# 2  .NET Developer Fresher 0-1 C#; VB.NET basics; ...
# 3  .NET Developer Fresher 0-1 C#; .NET Framework;...
# 4  .NET Developer Fresher 0-1 C#; ASP.NET; MVC; E...

# %% [markdown]
# ## Sentence Transformer

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
jd_embeddings = model.encode(df["JD_text"].tolist(), show_progress_bar=True)
# resume_embeddings =  np.load("model/resume_embeddings.npy")
resume_embeddings =  np.load("model/resume_embeddings.npy")

print('Success on import jd and resume embeddings.')
# Out:
# Batches: 100%|██████████| 34/34 [00:26<00:00,  1.28it/s]
# Success on import jd and resume embeddings.

# %%
df_resume.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0      Filename  \
# 0             0           0  10554236.pdf
# 1             1           1  10674770.pdf
# 2             2           2  11163645.pdf
# 3             3           3  11759079.pdf
# 4             4           4  12065211.pdf
#
#                                     Filepath  \
# 0  ../data/data/data/ACCOUNTANT\10554236.pdf
# 1  ../data/data/data/ACCOUNTANT\10674770.pdf
# 2  ../data/data/data/ACCOUNTANT\11163645.pdf
# 3  ../data/data/data/ACCOUNTANT\11759079.pdf
# 4  ../data/data/data/ACCOUNTANT\12065211.pdf
#
#                                       Extracted_Text    Category  \
# 0  ACCOUNTANT\nSummary\nFinancial Accountant spec...  ACCOUNTANT
# 1  STAFF ACCOUNTANT\nSummary\nHighly analytical a...  ACCOUNTANT
# 2  ACCOUNTANT\nProfessional Summary\nTo obtain a ...  ACCOUNTANT
# 3  SENIOR ACCOUNTANT\nExperience\nCompany Name Ju...  ACCOUNTANT
# 4  SENIOR ACCOUNTANT\nProfessional Summary\nSenio...  ACCOUNTANT
#
#                                         Cleaned_Text
# 0  accountant summary financial accountant specia...
# 1  staff accountant summary highly analytical det...
# 2  accountant professional summary obtain positio...
# 3  senior accountant experience company name june...
# 4  senior accountant professional summary senior ...

# %%
df_resume.shape
# Out:
# (2484, 7)

# %% [markdown]
# ## Match JD to Resume
# ### Method 1: Pure semantic matching using Sentence-BERT
#
# Purpose -> real ranking
#
# Sentence-BERT embeddings:
#
# - understand meaning / capture context
#
# - are pre-trained on massive NLI + semantic similarity datasets
#
# - excel at resume ↔ JD matching (industry-standard approach)

# %%
def match_jd_to_resumes(jd_embeddings, top_k=10): 
    # accept 1-D embedding or 2-D (1, dim) 
    emb = np.asarray(jd_embeddings) 
    if emb.ndim == 2 and emb.shape[0] == 1: 
        emb = emb[0] 
    if emb.ndim != 1: 
        raise ValueError("jd_embeddings must be a 1-D embedding vector or a 2-D array with shape (1, dim)") 
    scores = cosine_similarity(emb.reshape(1, -1), resume_embeddings).flatten() 
    # Safely handle cases where resume_embeddings length and df_resume length differ. 
    # We compute sorted indices by score, then filter only those indices that exist in df_resume. 
    sorted_idx = scores.argsort()[::-1] 
    valid_idx = [int(i) for i in sorted_idx if i < len(df_resume)] 
    if len(valid_idx) == 0: 
        # return empty dataframe with score column if no valid resumes available 
        results = df_resume.iloc[[]].copy() 
        results["score"] = [] 
        return results 
    top_k = min(top_k, len(valid_idx)) 
    top_idx = valid_idx[:top_k] 
    results = df_resume.iloc[top_idx].copy() 
    results["score"] = scores[np.array(top_idx)] 
    return results

# %%
test_jd = df["JD_text"].iloc[0]
jd_embedding = model.encode(test_jd, normalize_embeddings=True)
print(test_jd)
match_jd_to_resumes(jd_embedding, top_k=10)
# Out:
# .NET Developer Fresher 0-1 C#; VB.NET basics; .NET Framework; .NET Core fundamentals; ASP.NET; MVC; HTML; CSS; JavaScript basics; SQL Server; Entity Framework basics; LINQ; Visual Studio; Git; Unit Testing basics Assist in coding and debugging applications; Learn and apply .NET Framework and Core fundamentals; Support team in building ASP.NET MVC web applications; Write basic SQL queries and work with Entity Framework; Collaborate with peers to solve issues; Participate in code reviews for learning; Follow best practices in coding; Work with version control (Git) .NET; C#; ASP.NET MVC; Entity Framework; SQL Server; LINQ; Visual Studio; Unit Testing
#       Unnamed: 0.1  Unnamed: 0      Filename  \
# 2102          2102        2102  26746496.pdf
# 2059          2059        2059  16186411.pdf
# 2048          2048        2048  12763627.pdf
# 742            742         742  39247950.pdf
# 1331          1331        1331  35990852.pdf
# 2148          2148        2148  83816738.pdf
# 2080          2080        2080  20674668.pdf
# 2112          2112        2112  28126340.pdf
# 766            766         766  99124477.pdf
# 1356          1356        1356  85101052.pdf
#
#                                                Filepath  \
# 2102  ../data/data/data/INFORMATION-TECHNOLOGY\26746...
# 2059  ../data/data/data/INFORMATION-TECHNOLOGY\16186...
# 2048  ../data/data/data/INFORMATION-TECHNOLOGY\12763...
# 742              ../data/data/data/BANKING\39247950.pdf
# 1331            ../data/data/data/DESIGNER\35990852.pdf
# 2148  ../data/data/data/INFORMATION-TECHNOLOGY\83816...
# 2080  ../data/data/data/INFORMATION-TECHNOLOGY\20674...
# 2112  ../data/data/data/INFORMATION-TECHNOLOGY\28126...
# 766              ../data/data/data/BANKING\99124477.pdf
# 1356            ../data/data/data/DESIGNER\85101052.pdf
#
#                                          Extracted_Text  \
# 2102  DATABASE PROGRAMMER/ANALYST (.NET DEVELOPER)\n...
# 2059  DATABASE PROGRAMMER/ANALYST (.NET DEVELOPER)\n...
# 2048  ASP.NET WEB DEVELOPER\nAccomplishments\nWon As...
# 742   SOFTWARE ENGINEER\nQualifications\nC# 3.0, PL/...
# 1331  WEBSITE DESIGNER\nSummary\nSoftware developer ...
# 2148  INFORMATION TECHNOLOGY INTERN (TEST AUTOMATION...
# 2080  INFORMATION TECHNOLOGY SPECIALIST III (DRUPAL ...
# 2112  INFORMATION TECHNOLOGY COORDINATOR\nProfession...
# 766   ASSOCIATE CONSULTANT\nProfessional Summary\n7+...
# 1356  TECHNICAL DESIGNER\nCareer Overview\nâ—​Â Havi...
#
#                     Category  \
# 2102  INFORMATION-TECHNOLOGY
# 2059  INFORMATION-TECHNOLOGY
# 2048  INFORMATION-TECHNOLOGY
# 742                  BANKING
# 1331                DESIGNER
# 2148  INFORMATION-TECHNOLOGY
# 2080  INFORMATION-TECHNOLOGY
# 2112  INFORMATION-TECHNOLOGY
# 766                  BANKING
# 1356                DESIGNER
#
#                                            Cleaned_Text     score
# 2102  database programmer analyst net developer summ...  0.614708
# 2059  database programmer analyst net developer summ...  0.584151
# 2048  asp net web developer accomplishments associat...  0.540443
# 742   software engineer qualifications c pl sql java...  0.513053
# 1331  website designer summary software developer we...  0.510468
# 2148  information technology intern test automation ...  0.505999
# 2080  information technology specialist drupal dev s...  0.487816
# 2112  information technology coordinator professiona...  0.474242
# 766   associate consultant professional summary year...  0.471596
# 1356  technical designer career overview years exper...  0.470555

# %% [markdown]
# ### Method 2: Hybrid (Semantic + Keywords)
#
# Purpose -> Explain why its fits
#
# `final_scores = (weight_semantic [0.7] * semantic_scores) + \
#                 (weight_keyword [0.3] * keyword_scores)`
#
# The 2nd (hybrid) performed worse because:
# - keyword scoring introduced noise
#
# - weights distorted ranking
#
# - keywords are often generic and unreliable
#
# - SBERT already captures those concepts better

# %% [markdown]
# #### Normalization (matches your Cleaned_Text style)

# %%
def normalize_for_match(text: str) -> str:
    if not isinstance(text, str):
        return ""
    text = text.lower()
    text = re.sub(r"[^a-z0-9\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

# %% [markdown]
# #### Extract JD keywords

# %%
def extract_keywords(jd_keywords):
    if not isinstance(jd_keywords, str):
        return []
    jd_keywords = jd_keywords.replace(";", ",")
    return [kw.strip() for kw in jd_keywords.split(",") if kw.strip()]

# %%
def keyword_score(resume_text, jd_keywords):
    resume_norm = normalize_for_match(resume_text)
    resume_tokens = set(resume_norm.split())

    matched = 0
    kws = extract_keywords(jd_keywords)

    for kw in kws:
        kw_norm = normalize_for_match(kw)
        kw_tokens = kw_norm.split()

        if kw_tokens and all(t in resume_tokens for t in kw_tokens):
            matched += 1

    return matched / max(1, len(kws))

# %%
def match_jd_to_resumes_method_2(jd_embedding, jd_keywords, 
                                 top_k=10, w_semantic=0.7, w_keyword=0.3):

    emb = np.asarray(jd_embedding)
    if emb.ndim == 2 and emb.shape[0] == 1:
        emb = emb[0]

    scores = cosine_similarity(emb.reshape(1, -1), resume_embeddings).flatten()

    kw_scores = []
    for _, row in df_resume.iterrows():
        txt = row.get("Cleaned_Text", "")
        kw_scores.append(keyword_score(txt, jd_keywords))

    kw_scores = np.array(kw_scores)

    if len(kw_scores) != len(scores):
        raise ValueError("Resume embeddings and df_resume not aligned")

    final = (w_semantic * scores) + (w_keyword * kw_scores)

    sorted_idx = final.argsort()[::-1][:top_k]

    results = df_resume.iloc[sorted_idx].copy()
    results["semantic_score"] = scores[sorted_idx]
    results["keyword_score"] = kw_scores[sorted_idx]
    results["final_score"] = final[sorted_idx]

    return results.sort_values(by="final_score", ascending=False)

# %%
jd = df.iloc[0]

jd_text = jd["JD_text"]
jd_keywords = jd["Keywords"]

jd_embedding = model.encode(jd_text, normalize_embeddings=True)


match_jd_to_resumes_method_2(jd_embedding, jd_keywords, top_k=10)
# Out:
#       Unnamed: 0.1  Unnamed: 0      Filename  \
# 2102          2102        2102  26746496.pdf
# 2059          2059        2059  16186411.pdf
# 1331          1331        1331  35990852.pdf
# 1225          1225        1225  43311839.pdf
# 2048          2048        2048  12763627.pdf
# 1556          1556        1556  51588273.pdf
# 2035          2035        2035  10089434.pdf
# 742            742         742  39247950.pdf
# 2080          2080        2080  20674668.pdf
# 2148          2148        2148  83816738.pdf
#
#                                                Filepath  \
# 2102  ../data/data/data/INFORMATION-TECHNOLOGY\26746...
# 2059  ../data/data/data/INFORMATION-TECHNOLOGY\16186...
# 1331            ../data/data/data/DESIGNER\35990852.pdf
# 1225          ../data/data/data/CONSULTANT\43311839.pdf
# 2048  ../data/data/data/INFORMATION-TECHNOLOGY\12763...
# 1556         ../data/data/data/ENGINEERING\51588273.pdf
# 2035  ../data/data/data/INFORMATION-TECHNOLOGY\10089...
# 742              ../data/data/data/BANKING\39247950.pdf
# 2080  ../data/data/data/INFORMATION-TECHNOLOGY\20674...
# 2148  ../data/data/data/INFORMATION-TECHNOLOGY\83816...
#
#                                          Extracted_Text  \
# 2102  DATABASE PROGRAMMER/ANALYST (.NET DEVELOPER)\n...
# 2059  DATABASE PROGRAMMER/ANALYST (.NET DEVELOPER)\n...
# 1331  WEBSITE DESIGNER\nSummary\nSoftware developer ...
# 1225  IT CONSULTANT\nSummary\nOver Seven years of So...
# 2048  ASP.NET WEB DEVELOPER\nAccomplishments\nWon As...
# 1556  SOFTWARE ENGINEERING MANAGER\nSummary\nMultifa...
# 2035  INFORMATION TECHNOLOGY TECHNICIAN I\nSummary\n...
# 742   SOFTWARE ENGINEER\nQualifications\nC# 3.0, PL/...
# 2080  INFORMATION TECHNOLOGY SPECIALIST III (DRUPAL ...
# 2148  INFORMATION TECHNOLOGY INTERN (TEST AUTOMATION...
#
#                     Category  \
# 2102  INFORMATION-TECHNOLOGY
# 2059  INFORMATION-TECHNOLOGY
# 1331                DESIGNER
# 1225              CONSULTANT
# 2048  INFORMATION-TECHNOLOGY
# 1556             ENGINEERING
# 2035  INFORMATION-TECHNOLOGY
# 742                  BANKING
# 2080  INFORMATION-TECHNOLOGY
# 2148  INFORMATION-TECHNOLOGY
#
#                                            Cleaned_Text  semantic_score  \
# 2102  database programmer analyst net developer summ...        0.614708
# 2059  database programmer analyst net developer summ...        0.584151
# 1331  website designer summary software developer we...        0.510468
# 1225  consultant summary seven years software applic...        0.466130
# 2048  asp net web developer accomplishments associat...        0.540443
# 1556  software engineering manager summary multiface...        0.467650
# 2035  information technology technician summary vers...        0.465147
# 742   software engineer qualifications c pl sql java...        0.513053
# 2080  information technology specialist drupal dev s...        0.487816
# 2148  information technology intern test automation ...        0.505999
#
#       keyword_score  final_score
# 2102          0.875     0.692795
# 2059          0.875     0.671406
# 1331          1.000     0.657328
# 1225          1.000     0.626291
# 2048          0.625     0.565810
# 1556          0.625     0.514855
# 2035          0.625     0.513103
# 742           0.500     0.509137
# 2080          0.500     0.491471
# 2148          0.375     0.466700

# %% [markdown]
# ### Method 3: Semantic Ranking + Keyword EXPLANATION ONLY

# %%
def explain_fit_only(resume_text, jd_keywords):
    resume_norm = normalize_for_match(resume_text)
    resume_tokens = set(resume_norm.split())

    matched = []

    for raw_kw in extract_keywords(jd_keywords):
        kw_norm = normalize_for_match(raw_kw)
        kw_tokens = kw_norm.split()

        if kw_tokens and all(t in resume_tokens for t in kw_tokens):
            matched.append(raw_kw)

    return ", ".join(matched) if matched else "No matching keywords"

def missing_skills_only(resume_text, jd_keywords):
    resume_norm = normalize_for_match(resume_text)
    resume_tokens = set(resume_norm.split())

    missing = []

    for raw_kw in extract_keywords(jd_keywords):
        kw_norm = normalize_for_match(raw_kw)
        kw_tokens = kw_norm.split()

        # skill is missing if any token isn't present
        if not (kw_tokens and all(t in resume_tokens for t in kw_tokens)):
            missing.append(raw_kw)
    return ", ".join(missing) if missing else "None"

def match_jd_to_resumes_method_3(jd_embedding, jd_keywords, top_k=10):
    results = match_jd_to_resumes(jd_embedding, top_k)

    results["Why it fits?"] = results["Cleaned_Text"].apply(
        lambda txt: explain_fit_only(txt, jd_keywords)
    )

    results["Missing skilss"] = results["Cleaned_Text"].apply(
        lambda txt: missing_skills_only(txt, jd_keywords)

    )

    return results

# %%
jd = df.iloc[0]

jd_text = jd["JD_text"]
jd_keywords = jd["Keywords"]

jd_embedding = model.encode(jd_text, normalize_embeddings=True)


match_jd_to_resumes_method_3(jd_embedding, jd_keywords, top_k=10)
# Out:
#       Unnamed: 0.1  Unnamed: 0      Filename  \
# 2102          2102        2102  26746496.pdf
# 2059          2059        2059  16186411.pdf
# 2048          2048        2048  12763627.pdf
# 742            742         742  39247950.pdf
# 1331          1331        1331  35990852.pdf
# 2148          2148        2148  83816738.pdf
# 2080          2080        2080  20674668.pdf
# 2112          2112        2112  28126340.pdf
# 766            766         766  99124477.pdf
# 1356          1356        1356  85101052.pdf
#
#                                                Filepath  \
# 2102  ../data/data/data/INFORMATION-TECHNOLOGY\26746...
# 2059  ../data/data/data/INFORMATION-TECHNOLOGY\16186...
# 2048  ../data/data/data/INFORMATION-TECHNOLOGY\12763...
# 742              ../data/data/data/BANKING\39247950.pdf
# 1331            ../data/data/data/DESIGNER\35990852.pdf
# 2148  ../data/data/data/INFORMATION-TECHNOLOGY\83816...
# 2080  ../data/data/data/INFORMATION-TECHNOLOGY\20674...
# 2112  ../data/data/data/INFORMATION-TECHNOLOGY\28126...
# 766              ../data/data/data/BANKING\99124477.pdf
# 1356            ../data/data/data/DESIGNER\85101052.pdf
#
#                                          Extracted_Text  \
# 2102  DATABASE PROGRAMMER/ANALYST (.NET DEVELOPER)\n...
# 2059  DATABASE PROGRAMMER/ANALYST (.NET DEVELOPER)\n...
# 2048  ASP.NET WEB DEVELOPER\nAccomplishments\nWon As...
# 742   SOFTWARE ENGINEER\nQualifications\nC# 3.0, PL/...
# 1331  WEBSITE DESIGNER\nSummary\nSoftware developer ...
# 2148  INFORMATION TECHNOLOGY INTERN (TEST AUTOMATION...
# 2080  INFORMATION TECHNOLOGY SPECIALIST III (DRUPAL ...
# 2112  INFORMATION TECHNOLOGY COORDINATOR\nProfession...
# 766   ASSOCIATE CONSULTANT\nProfessional Summary\n7+...
# 1356  TECHNICAL DESIGNER\nCareer Overview\nâ—​Â Havi...
#
#                     Category  \
# 2102  INFORMATION-TECHNOLOGY
# 2059  INFORMATION-TECHNOLOGY
# 2048  INFORMATION-TECHNOLOGY
# 742                  BANKING
# 1331                DESIGNER
# 2148  INFORMATION-TECHNOLOGY
# 2080  INFORMATION-TECHNOLOGY
# 2112  INFORMATION-TECHNOLOGY
# 766                  BANKING
# 1356                DESIGNER
#
#                                            Cleaned_Text     score  \
# 2102  database programmer analyst net developer summ...  0.614708
# 2059  database programmer analyst net developer summ...  0.584151
# 2048  asp net web developer accomplishments associat...  0.540443
# 742   software engineer qualifications c pl sql java...  0.513053
# 1331  website designer summary software developer we...  0.510468
# 2148  information technology intern test automation ...  0.505999
# 2080  information technology specialist drupal dev s...  0.487816
# 2112  information technology coordinator professiona...  0.474242
# 766   associate consultant professional summary year...  0.471596
# 1356  technical designer career overview years exper...  0.470555
#
#                                            Why it fits?  \
# 2102  .NET, C#, ASP.NET MVC, Entity Framework, SQL S...
# 2059  .NET, C#, ASP.NET MVC, Entity Framework, SQL S...
# 2048   .NET, C#, ASP.NET MVC, SQL Server, Visual Studio
# 742                 .NET, C#, SQL Server, Visual Studio
# 1331  .NET, C#, ASP.NET MVC, Entity Framework, SQL S...
# 2148                       C#, SQL Server, Unit Testing
# 2080        C#, SQL Server, Visual Studio, Unit Testing
# 2112                    .NET, SQL Server, Visual Studio
# 766                              .NET, C#, Unit Testing
# 1356                       C#, SQL Server, Unit Testing
#
#                                          Missing skilss
# 2102                                       Unit Testing
# 2059                                       Unit Testing
# 2048               Entity Framework, LINQ, Unit Testing
# 742   ASP.NET MVC, Entity Framework, LINQ, Unit Testing
# 1331                                               None
# 2148  .NET, ASP.NET MVC, Entity Framework, LINQ, Vis...
# 2080          .NET, ASP.NET MVC, Entity Framework, LINQ
# 2112  C#, ASP.NET MVC, Entity Framework, LINQ, Unit ...
# 766   ASP.NET MVC, Entity Framework, SQL Server, LIN...
# 1356  .NET, ASP.NET MVC, Entity Framework, LINQ, Vis...

# %%
# df.to_csv('../data/data/processed_data/jd_data.csv')

import os
import datetime
import numpy as np
import pandas as pd
import json

today = datetime.datetime.now().strftime("%Y-%m-%d")

save_dir = f"model/{today}"
os.makedirs(save_dir, exist_ok=True)

# 2️⃣ Save embeddings
np.save(f"{save_dir}/resume_embeddings.npy", resume_embeddings)
np.save(f"{save_dir}/jd_embeddings.npy", jd_embeddings)


print("Saved version:", save_dir)
# Out:
# Saved version: model/2025-12-31
